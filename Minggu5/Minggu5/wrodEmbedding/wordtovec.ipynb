# %%
import os.path

import pandas as pd
from tqdm.auto import tqdm

from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec

# %%
df = pd.read_csv("data/gojek_review.csv")
df.head()
# Out:
#                                               review  rate
# 0  Sangat kecewa. Kecewa sekali. Udh top up. Mau ...     1
# 1  Ga niat ngasih promo sialan temen udh pake ref...     1
# 2  Kalau sistemnya rata begini apa bedanya yg raj...     1
# 3  Ongkosnya da mahal, minimal 16rb..... Sekarang...     1
# 4  Tolol anjing..!!!! Aplikasi yang katanga karya...     1

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

kalimat = [word_tokenize(review.lower())for review in tqdm (df.review)]
kalimat [5]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#   0%|          | 0/1277 [00:00<?, ?it/s]
# ['saya',
#  'tau',
#  'kalau',
#  'rating',
#  'itu',
#  'sangat',
#  'riskan',
#  '.',
#  'emosional',
#  'manusia',
#  'berbeda-beda',
#  'dalam',
#  'menanggapi',
#  'suatu',
#  'masalah',
#  '.',
#  'masalah',
#  'yang',
#  'berbobot',
#  'sampai',
#  'masalah',
#  'yang',
#  'kurang',
#  'berarti',
#  '.',
#  'tak',
#  'ada',
#  'apapun',
#  'bisa',
#  'terjadi',
#  '.',
#  'nilai',
#  'akan',
#  'berubah',
#  'arti',
#  '.',
#  'terima',
#  'kasih',
#  'gojek',
#  'untuk',
#  'indonesia',
#  '.']

# %%
from gensim.models import Word2Vec

model = Word2Vec(kalimat, vector_size=128, window=5, min_count=3, workers=4, epochs=1000, sg=0, hs=0)

# %% [markdown]
# Save

# %%
os.makedirs("model/w2v", exist_ok=True)

# %%
model.save("model/w2v/gojek_review.w2v")

# %% [markdown]
# Load

# %%
model = Word2Vec.load("model/w2V/gojek_review.w2v")

# %%
"Aplikasinya ngga nyaman dipake bule".lower().split()
# Out:
# ['aplikasinya', 'ngga', 'nyaman', 'dipake', 'bule']

# %%
contoh_data =[
    ['aplikasinya', 'ok', 'kok', '.', 'sangat', 'membantu', 'untuk', 'keseharan', 'saya'],
    ['aplikasinya', 'ngga', 'nyaman', 'dipake', 'bule']
]

# %%
model.train(contoh_data, total_examples=len(contoh_data), epochs=1)
# Out:
# (10, 14)

# %%
model.save("model/w2v/gojek_review.w2v")

# %% [markdown]
# Model Information

# %%
w2v = model.wv

# %%
word_list = w2v.index_to_key
# Menampilkan vocabulary
for word in word_list:
    print(word)
# Out:
# ,
# .
# saya
# !
# di
# gojek
# ..
# yg
# bisa
# ?
# ada
# nya
# driver
# dan
# ini
# aplikasi
# tidak
# yang
# gak
# mau
# lagi
# ga
# ...
# tolong
# aja
# sudah
# tapi
# untuk
# voucher
# padahal
# gopay
# ke
# sama
# udah
# order
# lebih
# akun
# sangat
# dengan
# ya
# buat
# sekarang
# kenapa
# jadi
# kasih
# malah
# lama
# dari
# gofood
# itu
# promo
# kalo
# jauh
# juga
# dapat
# pake
# karena
# masuk
# banyak
# terus
# kalau
# apa
# baru
# go
# dong
# kok
# gk
# kecewa
# pakai
# selalu
# harus
# pesan
# kualitas
# rata
# soal
# senilai
# bila
# mendingan
# ingat
# duduk
# jaringan
# entah
# peduli
# grabfood
# stiap
# 15
# balikin
# bgini
# dirumah
# ayo
# rame
# kak
# pembaruan
# manusia
# penjual
# tip
# jemputnya
# busuk
# donk
# mobile
# lapangan
# smoga
# 12
# mentri
# lama2
# nerima
# hadiah
# yaitu
# pengalaman
# membawa
# pt.gi
# tertulis
# dn
# terblokir
# performa
# mendadak
# lambat
# msih
# gmana
# macet
# aj
# dirugikan
# custumer
# maupun
# milih
# bca
# ngebid
# bantu
# alasannya
# plus
# mesan
# play
# mesti
# sayangnya
# siang
# krja
# awalnya
# juta
# 15k
# blom
# mas
# lari
# bantuan
# terbaik
# kompetitor
# berfungsi
# aspal
# call
# khususnya
# gopaynya
# center
# member
# setengah
# ntar
# kesal
# bkin
# dingin
# lokasinya
# supir
# 100rb
# total
# malem
# tai
# salam
# skema
# berjalan
# pengiriman
# ataupun
# nasib
# subuh
# amat
# bang
# bahwa
# ngeluh
# menurun
# berhasil
# 3x
# ......
# berada
# skarang
# diatas
# dijelaskan
# unggah
# selesai
# perubahan
# disini
# ratakan
# 15rb
# hrus
# sebab
# later
# helm
# mati
# manusiawi
# praktis
# turun
# rutin
# perhatikan
# seharian
# kesalahan
# td
# membutuhkan
# drver
# angkot
# aktifkan
# diskonnya
# infonya
# ngambil
# trims
# kn
# jas
# alhasil
# layanannya
# dibalas
# pajangan
# harap
# install
# mengurangi
# kmi
# berkali-kali
# notifikasi
# go-pay
# dibayar
# memikirkan
# jujur
# wahai
# nunggunya
# dicoba
# ;
# negeri
# tukang
# 23
# februari
# gausah
# lanjuti
# menurut
# 8
# peta
# dicancel
# pekerjaan
# jga
# ditanggapi
# jadikan
# megang
# bangke
# tiga
# bisa2
# instan
# fix
# anter
# ngojek
# area
# ngomong
# nakal
# terjangkau
# nyiksa
# kevin
# ovo
# tim
# negara
# naek
# kurangin
# dpet
# ngerasa
# adain
# makanya
# akses
# bagian
# skrang
# pengemudi
# 50k
# dibantu
# dear
# kadaluarsa
# diberi
# maki
# jumlah
# selisih
# asu
# pembayarannya
# memperhatikan
# cma
# penyelesaian
# metode
# membuka
# berbeda
# kehadiran
# on
# unistal
# iklan
# gimna
# uangnya
# pdahal
# suami
# menyusahkan
# terkesan
# jaya
# festival
# fast
# umur
# mengikuti
# berpikir
# rasanya
# akhir2
# kejauhan
# lipat
# antri
# kah
# saudara
# muda
# bgtu
# mempersulit
# mnta
# hahaha
# bermutu
# makassar
# kyak
# terdeteksi
# suspend
# bebek
# hasilnya
# dikarenakan
# kos
# kesempatan
# konsisten
# gangguan
# maksa
# please
# desember
# 2019
# disama
# sekalian
# dompet
# out
# bbm
# berarti
# lima
# masukkan
# minus
# tersedia
# panjang
# seribu
# menipu
# raib
# poto
# meski
# lanjut
# beneran
# ksh
# kelamaan
# ancur
# nanya
# gaji
# facebook
# selanjutnya
# amburadul
# nah
# delay
# woi
# pnya
# back
# ndak
# layarnya
# cache
# gang
# kaki
# cuk
# kolom
# disekitar
# tupo
# 1jam
# melihat
# miris
# onbid
# tengah
# bacaan
# didepan
# selain
# terkadang
# sistim
# ajh
# menteri
# serius
# top-up
# berlangganan
# alesan
# besok
# kilo
# roda
# sepeda
# sepihak
# hargai
# drivermu
# selfie
# paylaternya
# lampung
# situ
# say
# pajak
# nelpon
# tega
# kodenya
# kantornya
# tdi
# blok
# kinerja
# warung
# lapor
# darah
# bersahabat
# cacat
# systemnya
# dapetnya
# org2
# pt.gojek
# dibuka
# terkait
# malahan
# mw
# ayam
# menguntungkan
# perbaharui
# emg
# bersama
# skali
# mksh
# 8rb
# plat
# arah
# buta
# banned
# transfortasi
# tipu
# betul
# kebijakannya
# kurangi
# yh
# memory
# posisinya
# ikhlas
# karyawan
# kira
# komplen
# swadaya
# kapanpun
# sh
# mengantarkan
# ringan
# diem
# ak
# bagusan
# 6
# tks
# prank
# 75
# bantuanya
# restart
# profesional
# berangkat
# denger
# pemakaian
# ngejar
# smakin
# buru-buru
# anjir
# kpd
# handphone
# efektif
# alangkah
# penghasilan
# menghubungi
# nyebelin
# mitranya
# ky
# jawabannya
# hadeh
# gajelas
# obat
# minum
# dipakek
# ratusan
# diturunin
# ktpnya
# argo
# makarim
# gampang
# apalah
# depannya
# sayangkan
# nadim
# berakhir
# berpergian
# terlebih
# ngadain
# jenis
# ampe
# s
# legend
# ucapkan
# menyediakan
# pusing
# bepergian
# misalnya
# indah
# sayaa

# %%
w2v.vectors
# Out:
# array([[-6.8131857e-02,  1.7955010e+00,  1.2959815e+00, ...,
#          5.5915844e-01, -1.0826966e+00,  9.1669726e-01],
#        [-3.6486572e-01,  2.6202705e+00,  7.3393309e-01, ...,
#         -1.4967108e+00, -5.9136450e-01, -7.8119427e-02],
#        [ 4.0732590e-03,  2.1039615e+00, -3.0403614e-01, ...,
#          4.7093281e-01, -9.6752107e-01, -2.6570740e-01],
#        ...,
#        [-1.5434208e+00,  4.1693802e+00, -1.1652606e+00, ...,
#         -5.5025870e-01, -1.3783494e+00,  8.6615574e-01],
#        [ 9.8752141e-01,  1.0513481e+00, -1.4951378e+00, ...,
#          1.5589491e-01, -6.1661911e-01,  8.7529728e-03],
#        [ 2.5259950e+00, -1.5513175e+00, -9.2911083e-01, ...,
#         -8.1759262e-01, -6.5314573e-01, -9.4670665e-01]], dtype=float32)

# %%
w2v.vector_size
# Out:
# 128

# %%
w2v["gofood"]
# Out:
# array([-1.1789359 ,  1.0198808 ,  0.39349586,  1.463972  , -0.41138574,
#         0.28059334,  0.27952385, -3.2916183 , -0.98829836,  1.3815241 ,
#        -2.1278546 ,  0.75993   , -0.32107854,  0.1371543 ,  2.6353154 ,
#        -2.9238071 ,  5.154496  , -0.22093758, -0.03185822, -1.4235834 ,
#        -1.1356742 , -1.5486937 , -2.7916691 ,  1.9335396 ,  1.3807801 ,
#         1.7193022 ,  1.9874903 ,  0.5343924 , -3.543924  , -0.1912431 ,
#        -0.705996  ,  3.3753593 ,  0.68112373,  0.13631801, -1.2683302 ,
#         4.882103  , -2.1498265 , -0.34004933, -3.0452309 , -1.1011249 ,
#         3.5160098 , -2.0921974 ,  3.0545015 ,  1.6584575 , -0.9163269 ,
#         4.0340385 ,  3.0057108 ,  2.0509515 ,  7.112965  , -3.254286  ,
#        -2.355459  ,  0.34639278, -1.3261272 ,  0.80863947,  1.1482813 ,
#         0.02696382,  3.089878  ,  3.749757  ,  3.5230932 , -1.0205739 ,
#         2.8196154 , -0.15194948, -0.1449382 , -1.2376249 ,  0.5884134 ,
#         1.4681177 , -0.601116  ,  1.0943817 , -2.9546905 ,  3.5834801 ,
#         3.4833581 ,  1.2549517 ,  2.0326135 ,  3.3658197 ,  1.0012642 ,
#        -3.1515858 ,  2.2108665 , -0.3642031 ,  0.42393678, -3.7134833 ,
#        -1.2624234 ,  0.3022855 , -1.1693602 , -3.0979593 , -0.17113918,
#         0.8119159 ,  1.8492993 , -5.0438952 , -2.6209714 ,  1.2611616 ,
#         0.7443975 , -0.09979059,  2.5986514 , -0.67894596,  0.7960241 ,
#        -1.1465596 ,  7.78324   ,  0.9470227 ,  1.9736558 , -1.4532313 ,
#         0.4267083 ,  4.1195393 , -2.2238739 ,  0.74585426,  1.1482774 ,
#         1.5626647 , -1.354911  , -1.1521535 ,  2.6833427 ,  0.01244525,
#         2.2127204 , -3.1956408 , -2.4089632 , -1.2649571 ,  0.28060994,
#         2.8589716 ,  1.0588069 ,  1.2591572 , -0.8544606 , -1.1165838 ,
#         3.2114387 , -3.8239546 , -1.6969852 , -1.3890114 , -1.3739718 ,
#        -3.172857  , -2.1287928 ,  1.4711918 ], dtype=float32)

# %% [markdown]
# simillar word

# %%
w2v.similar_by_word("nadiem", topn=5)
# Out:
# [('pegang', 0.38865286111831665),
#  ('nadim', 0.36972373723983765),
#  ('makarim', 0.36730948090553284),
#  ('mentri', 0.308843195438385),
#  ('awalnya', 0.30472084879875183)]

# %%
from umap import UMAP
import numpy as np
import pandas as pd
import plotly.express as px

# %%
X = UMAP().fit_transform(w2v.vectors)

# %%
df = pd.DataFrame(X, columns=["umap1","umap2"])
df["text"] = w2v.index_to_key

# %%
df
# Out:
#          umap1     umap2       text
# 0     7.073197  0.177149          ,
# 1     6.490988  0.137505          .
# 2     5.638968  0.397539       saya
# 3     7.714627  0.052922          !
# 4     5.841241  0.062780         di
# ...        ...       ...        ...
# 1694  6.948564 -0.609222     pusing
# 1695  5.840441 -1.593202  bepergian
# 1696  8.389682 -0.031011   misalnya
# 1697  6.753884 -2.540501      indah
# 1698  7.935016  0.538513      sayaa
#
# [1699 rows x 3 columns]

# %%
fig = px.scatter(df, x="umap1" , y="umap2", text="text")
fig.update_traces(textposition='top center')
fig.update_layout(
    height=8000,
    title_text='Reduced Word2Vec Visualization'
)
fig.show()
